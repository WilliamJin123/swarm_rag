# %%
from test_swarm_on_stark import test_first_10_questions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from test_swarm_on_stark import test_first_10_questions
#
# File c:\Users\jinwi\programming_files_NEW\swarm_rag_experiment\stark\test_swarm_on_stark.py:7
#       4 import pandas as pd
#       5 from typing import List, Dict, Any, Union
# ----> 7 from swarm_rag.core import Heuristics, SwarmRetriever
#       8 from swarm_rag.integrations.stark import StarkInMemoryVectorStore, StarkPreComputedEmbeddingHandler, StarkSKBAdapter
#       9 from swarm_rag.eval.metrics import Evaluator
#
# ModuleNotFoundError: No module named 'swarm_rag'
